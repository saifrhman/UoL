# %%
class LLMChessAgent:
    def __init__(self, api_key="your_key"):
        self.name = "GPT-Chess"

    def get_move(self, board):
        # TODO: 1. Convert board to FEN or PGN format
        board_fen = board.fen()
        legal_moves = [move.uci() for move in board.legal_moves]
        
        # TODO: 2. Construct a prompt
        prompt = f"""You are a chess grandmaster. 
        Current Board (FEN): {board_fen}
        Legal moves: {', '.join(legal_moves)}
        Which move do you choose? Return ONLY the move in UCI format (e.g., e2e4)."""

        # TODO: 3. Call your LLM (OpenAI, Anthropic, or local Llama)
        # response = call_llm(prompt)
        
        # TODO: 4. VALIDATION (CRITICAL for marks)
        # if response in legal_moves:
        #     return chess.Move.from_uci(response)
        # else:
        #     # Fallback strategy: Pick a random move if LLM is invalid
        #     return random.choice(list(board.legal_moves))

# TODO: 5. Evaluation metrics (Requirement: win/draw/loss rates)
def run_evaluation(agent, opponent, rounds=20):
    stats = {"wins": 0, "losses": 0, "draws": 0, "history": []}
    # ... loop and play_match ...
    return stats
